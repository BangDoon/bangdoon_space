# %%
import numpy as np
import pandas as pd
import scipy.optimize as sp
import xgboost as xgb

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Kaggle/SPAM_Detection/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Kaggle/SPAM_Detection/test.csv')
label_data = pd.read_csv('/content/drive/MyDrive/Kaggle/SPAM_Detection/train_labels.csv')

# %%
train_data.head()
# Out:
#    0.097094   1.1133     45.038  0.88184  ...  2.4517  3.3373  0.065201  0.091158
# 0  0.050086  0.11158    94.0800  1.76500  ...  1.9795  3.5064  0.072132  0.091950
# 1  0.088447  2.36340     5.0580  0.14436  ...  3.3087  2.9969  0.064328  0.036793
# 2  0.772540  0.59469        NaN  0.97515  ...  2.5237  2.1711  0.080865  0.081553
# 3  0.382410  4.81090  1955.1000  0.46050  ...  4.6262  3.1947       NaN  0.187180
# 4  0.081316  4.84150     4.0507  2.48320  ...  3.3041  0.1922  0.032600  0.050172
#
# [5 rows x 100 columns]

# %%
#행이 정의되어 있지 않기 때문에 임의의 행 이름을 정해준다.
col = list((range(0,100)))
train_data.columns = [col]
test_data.columns = [col]

# %%
train_data.head()
# Out:
#          0        1          2        3   ...      96      97        98        99
# 0  0.050086  0.11158    94.0800  1.76500  ...  1.9795  3.5064  0.072132  0.091950
# 1  0.088447  2.36340     5.0580  0.14436  ...  3.3087  2.9969  0.064328  0.036793
# 2  0.772540  0.59469        NaN  0.97515  ...  2.5237  2.1711  0.080865  0.081553
# 3  0.382410  4.81090  1955.1000  0.46050  ...  4.6262  3.1947       NaN  0.187180
# 4  0.081316  4.84150     4.0507  2.48320  ...  3.3041  0.1922  0.032600  0.050172
#
# [5 rows x 100 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 100 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   (0,)    584 non-null    float64
#  1   (1,)    589 non-null    float64
#  2   (2,)    579 non-null    float64
#  3   (3,)    579 non-null    float64
#  4   (4,)    574 non-null    float64
#  5   (5,)    583 non-null    float64
#  6   (6,)    586 non-null    float64
#  7   (7,)    582 non-null    float64
#  8   (8,)    580 non-null    float64
#  9   (9,)    580 non-null    float64
#  10  (10,)   586 non-null    float64
#  11  (11,)   583 non-null    float64
#  12  (12,)   585 non-null    float64
#  13  (13,)   576 non-null    float64
#  14  (14,)   572 non-null    float64
#  15  (15,)   583 non-null    float64
#  16  (16,)   577 non-null    float64
#  17  (17,)   587 non-null    float64
#  18  (18,)   582 non-null    float64
#  19  (19,)   578 non-null    float64
# ...

# %%
# train_data의 info()를 보면 개수가 맞지않는 것을 볼 수 있다. = NULL 값이 있다.
# null값을 채워주자. #중앙값 #inplace 는 원본이 바뀌어도 상관없을때 사용
#for i in col:
#  fill_train_data = train_data[i,].fillna(train_data[i,].median())

fill_train_data = train_data.fillna(train_data.median())

fill_test_data = test_data.fillna(test_data.median())

# %%
# 라벨의 shape이 599,1 로 되어있어서  일렬로 펼쳐준다. 
y_train = np.ravel(label_data)
y_train.shape
# Out:
# (599,)

# %%
x_train = train_data
x_test = test_data

x_train.shape
# Out:
# (599, 100)
